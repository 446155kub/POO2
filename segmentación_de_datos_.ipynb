# %% [markdown]
# # creacion de una base de datos

# %%
est = {"1 dato":[1,6,7,4,4], "2 dato":[6,8,1,2,3], "3 dato":[7,3,5,9,8], "4 dato":[8,6,5,1,4],"5 dato":[7,8,4,1,9]} #creamos diferntes listas
type (est) #dice de que tipo de texto es esto
dict
# Out:
# dict

# %%
import pandas as pd #Importa paneles

# %%
pd.DataFrame(est)
# Out:
#    1 dato  2 dato  3 dato  4 dato  5 dato
# 0       1       6       7       8       7
# 1       6       8       3       6       8
# 2       7       1       5       5       4
# 3       4       2       9       1       1
# 4       4       3       8       4       9

# %% [markdown]
# #Lectura de datos a traves de una API
# ##Un mecanismo que permite que dos componentes de software se comuniquen entre sí utilizando un conjunto de definiciones y protocolos.
#
# [API](https://aws.amazon.com/es/what-is/api/#:~:text=Las%20API%20son%20mecanismos%20que,meteorolog%C3%ADa%20contiene%20datos%20meteorol%C3%B3gicos%20diarios.)

# %%
import yfinance as yf #Importar datos financieros

# %%
ticker ="AAPL"

aapl = yf.download(ticker,"2020-01-01", end = "2024-01-01") #descargamos las acciones  de apple.
aapl
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   74.059998   75.150002   73.797501   75.087502   73.059425
# 2020-01-03   74.287498   75.144997   74.125000   74.357498   72.349129
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   72.925644
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   72.582672
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   73.750237
# ...                ...         ...         ...         ...         ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006  193.353287
# 2023-12-26  193.610001  193.889999  192.830002  193.050003  192.803986
# 2023-12-27  192.490005  193.500000  191.089996  193.149994  192.903839
# 2023-12-28  194.139999  194.660004  193.169998  193.580002  193.333298
# 2023-12-29  193.899994  194.399994  191.729996  192.529999  192.284637
#
#                Volume
# Date
# ...
